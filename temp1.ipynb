# %%
from ultralytics import YOLO

# %%
# object detection
model1 = YOLO("yolo26x.pt")
result1 = model1("asets/image1.png")

# %%
# if you want to used the live camera\
result1 = model1(0,save=True)

# %%
# segment detection
model1 = YOLO("yolo26x-seg.pt")
result2 = model1("asets/image1.png")

# %%
# segmentation
model1 = YOLO("yolo26x-cls.pt")
result3 = model1("asets/image1.png")
